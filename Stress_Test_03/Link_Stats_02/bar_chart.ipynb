# %%
import pandas as pd               # import the data
import seaborn as sns             # data visualization
from collections import Counter   # data countaine (storage)
import matplotlib.pyplot as plt   # plot the data
from matplotlib import pyplot as plt,ticker
import numpy as np                # numerical mathematics
from scipy import stats           # scientific mathematic algorithms
import pickle                     # read python objects from disk

# read the dictionary directly
with open('link_dict.pkl', 'rb') as fp:
    data = pickle.load(fp)
    print('Dictionary read')
    print(data)
# transform data
bond = list(data.keys())
count = list(data.values())

# create a plot to work on
fig, ax = plt.subplots(figsize=(10, 10))

# create a title for the plot
plt.title("QM-MM bonds ordered by appearance", size=20)
plt.ylabel("bond type",size=16)
plt.xlabel("No. of bonds observerd",size=20)
plt.rcParams['font.size'] = 12

# add info
plt.text(1220, 43, "  750 cluster\n4259 QM-MM bonds", size=12)

# creating the bar plot
plt.barh(bond, count, height=0.75)

plt.tight_layout()
# plt.show()
plt.savefig('/dicos_ui_home/tlankau/QMMM/Link_Stats_02/stress03_bond_analysis.jpg', dpi=400)
# Out:
# Dictionary read
# {'c4c4': 1484, 'p4c4': 965, 'n3c4': 491, 'o2c4': 326, 'c3c4': 296, 'p3c4': 133, 'n4c4': 122, 'o2s4': 80, 'b4c4': 64, 'si4c4': 40, 'n2c4': 37, 's2c4': 31, 'c4c1': 24, 'c2b4': 22, 'c4si4': 21, 'c4c3': 10, 'si3c4': 10, 'n3si4': 9, 'c4n5': 8, 'b4f1': 8, 'o2p5': 8, 'c3si4': 7, 'b4n3': 6, 'c4o2': 6, 'c2c4': 5, 'b3c4': 4, 'c3n3': 4, 'n3s6': 4, 'si4si4': 4, 'n3b4': 4, 'o1cl1': 3, 'as3c4': 3, 'c2si4': 3, 'c4n3': 3, 's2si4': 2, 'h1b4': 2, 'c4n4': 2, 'n3n3': 2, 'c3c3': 1, 'o2b4': 1, 'n3c3': 1, 'se2c4': 1, 'b3c2': 1, 'p5c4': 1}
